# %%
# !wget https://raw.githubusercontent.com/keras-team/keras/master/examples/conv_filter_visualization.py -O conv_filter_visualization.py
# Out:
# --2019-04-30 20:16:51--  https://raw.githubusercontent.com/keras-team/keras/master/examples/conv_filter_visualization.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9646 (9.4K) [text/plain]
# Saving to: ‘conv_filter_visualization.py’
#
# conv_filter_visuali 100%[===================>]   9.42K  --.-KB/s    in 0s
#
# 2019-04-30 20:16:51 (137 MB/s) - ‘conv_filter_visualization.py’ saved [9646/9646]

# %%
import keras

# %%
from keras.models import load_model
model = load_model('keras.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
from conv_filter_visualization import *

# %%
M = visualize_layer(model, layer_name = "conv2d_48")

# %%
from IPython.display import Image
Image('vgg_conv2d_48_7x7.png')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_10 (InputLayer)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 112, 112, 64)      18496
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 28, 28, 64)        0
# ...
